# %%
# !pip install -r requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install hdbscan
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 40.6 MB/s  0:00:00
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# test data

# %%
# !python3 extract_fish_embeddings.py --image_dir ../cropped/cropped_test --output_file ../embeddings_files/fishnet_embeddings_test.npz
# Out:
# ✅ Using device: cpu
# 100%|███████████████████████████████████████| 7695/7695 [05:06<00:00, 25.12it/s]
# ✅ Saved 7695 embeddings to ../embeddings_files/fishnet_embeddings_test.npz

# %% [markdown]
# extract megadescriptor embeddings
# train # todo

# %%
! python3 extract_embeddings_megadescriptor.py --image_dir ../cropped/cropped_train --output_file ../embeddings_files/megadescriptor_embeddings_train.npz
# Out:
# config.json: 100%|█████████████████████████████| 610/610 [00:00<00:00, 2.22MB/s]
# pytorch_model.bin: 100%|██████████████████████| 473M/473M [00:03<00:00, 120MB/s]
# ../cropped/cropped_train/anemo_0_07.29_16.26.33_1_4_1.jpg
# ../cropped/cropped_train/anemo_0_07.21_20.26.33_8_4_4.jpg
# ../cropped/cropped_train/anemo_0_07.26_19.56.33_1_0_3.jpg
# ../cropped/cropped_train/anemo_0_07.25_13.08.33._11_1_2.jpg
# ../cropped/cropped_train/anemo_0_07.26_11.26.33_6_8_2.jpg
# ../cropped/cropped_train/anemo_0_07.25_16.38.33._2_3_1.jpg
# ../cropped/cropped_train/selected_frame_217965_10_1.jpg
# ../cropped/cropped_train/anemo_0_07.29_20.56.33_14_6_3.jpg
# ../cropped/cropped_train/anemo_0_07.28_15.56.33_41_0_1.jpg
# ../cropped/cropped_train/selected_frame_400708_4_1.jpg
# ../cropped/cropped_train/selected_frame_19477_2_1.jpg
# ../cropped/cropped_train/anemo_0_07.28_19.26.33_0_2_2.jpg
# ../cropped/cropped_train/anemo_0_07.27_18.08.33._0_2_4.jpg
# ../cropped/cropped_train/selected_frame_81907_1_3.jpg
# ...

# %% [markdown]
# test# todo

# %%
! python3 extract_embeddings_megadescriptor.py --image_dir ../cropped/cropped_test --output_file ../embeddings_files/megadescriptor_embeddings_test.npz
# Out:
# ../cropped/cropped_test/selected_frame_744669_14_1.jpg
# ../cropped/cropped_test/selected_frame_820549_2_1.jpg
# ../cropped/cropped_test/selected_frame_772848_3_1.jpg
# ../cropped/cropped_test/selected_frame_693950_7_3.jpg
# ../cropped/cropped_test/selected_frame_690614_14_1.jpg
# ../cropped/cropped_test/selected_frame_818423_18_1.jpg
# ../cropped/cropped_test/selected_frame_675212_7_1.jpg
# ../cropped/cropped_test/selected_frame_790006_2_1.jpg
# ../cropped/cropped_test/selected_frame_824689_1_1.jpg
# ../cropped/cropped_test/selected_frame_618125_10_2.jpg
# ../cropped/cropped_test/selected_frame_741950_16_1.jpg
# ../cropped/cropped_test/selected_frame_561407_7_1.jpg
# ../cropped/cropped_test/selected_frame_595452_10_1.jpg
# ../cropped/cropped_test/selected_frame_627446_6_2.jpg
# ../cropped/cropped_test/selected_frame_561407_5_1.jpg
# ../cropped/cropped_test/selected_frame_830472_5_3.jpg
# ../cropped/cropped_test/selected_frame_775544_2_1.jpg
# ...

# %% [markdown]
# K means fishnet

# %%
! python3 k_means.py --embedding_file ../embeddings_files/fishnet_embeddings_train.npz --n_clusters 9 --output_file ../fishnet_clusters/k_means_fishnet.npz
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../fishnet_clusters/k_means_fishnet.npz

# %%
! python3 ami.py --clustered_file ../fishnet_clusters/k_means_fishnet.npz
# Out:
# 📊 AMI Calculation Summary:
#    Total samples:          30877
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            30877
#
# ✅ Adjusted Mutual Information (AMI): 0.0629

# %% [markdown]
# Agglomerative clustering fishnet

# %%
! python3 agglomerative_clustering.py --embedding_file ../embeddings_files/fishnet_embeddings_train.npz --n_clusters 9 --output_file ../fishnet_clusters/ac_fishnet.npz
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../fishnet_clusters/ac_fishnet.npz

# %%
# !python3 ami.py --clustered_file ../fishnet_clusters/ac_fishnet.npz
# Out:
# 📊 AMI Calculation Summary:
#    Total samples:          30877
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            30877
#
# ✅ Adjusted Mutual Information (AMI): 0.0650

# %% [markdown]
# HDBSCAN fishnet

# %%
! python3 hdbscan_clustering.py --embedding_file ../embeddings_files/fishnet_embeddings_train.npz --min_cluster_size 10 --output_file ../fishnet_clusters/hdbscan_fishnet.npz
# Out:
# 🔍 Running HDBSCAN clustering...
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../fishnet_clusters/hdbscan_fishnet.npz

# %%
! python3 ami.py --clustered_file ../fishnet_clusters/hdbscan_fishnet.npz
# Out:
# 📊 AMI Calculation Summary:
#    Total samples:          30877
#    Cluster noise (-1):     20713
#    Invalid ground truths:  0
#    Used in AMI:            10164
#
# ✅ Adjusted Mutual Information (AMI): 0.2294

# %% [markdown]
# Megadescriptor k means

# %%
! python3 k_means.py --embedding_file ../embeddings_files/megadescriptor_embeddings_train.npz --n_clusters 9 --output_file ../megadescriptor_clusters/k_means_megadescriptor.npz
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../megadescriptor_clusters/k_means_megadescriptor.npz

# %%
! python3 ami.py --clustered_file ../megadescriptor_clusters/k_means_megadescriptor.npz
# Out:
# 📊 AMI Calculation Summary:
#    Total samples:          30877
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            30877
#
# ✅ Adjusted Mutual Information (AMI): 0.2662

# %% [markdown]
# AC megadescriptor

# %%
! python3 agglomerative_clustering.py --embedding_file ../embeddings_files/megadescriptor_embeddings_train.npz --n_clusters 9 --output_file ../megadescriptor_clusters/ac_megadescriptor.npz
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../megadescriptor_clusters/ac_megadescriptor.npz

# %%
! python3 ami.py --clustered_file ../megadescriptor_clusters/ac_megadescriptor.npz
# Out:
# 📊 AMI Calculation Summary:
#    Total samples:          30877
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            30877
#
# ✅ Adjusted Mutual Information (AMI): 0.0031

# %% [markdown]
# HDBSCAN megadescriptor

# %%
! python3 hdbscan_clustering.py --embedding_file ../embeddings_files/megadescriptor_embeddings_train.npz --min_cluster_size 10 --output_file ../megadescriptor_clusters/hdbscan_megadescriptor.npz
# Out:
# 🔍 Running HDBSCAN clustering...
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../megadescriptor_clusters/hdbscan_megadescriptor.npz

# %%
! python3 ami.py --clustered_file ../megadescriptor_clusters/hdbscan_megadescriptor.npz
# Out:
# 📊 AMI Calculation Summary:
#    Total samples:          30877
#    Cluster noise (-1):     26391
#    Invalid ground truths:  0
#    Used in AMI:            4486
#
# ✅ Adjusted Mutual Information (AMI): 0.3342
