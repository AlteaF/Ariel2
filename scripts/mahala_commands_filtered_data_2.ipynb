# %% [markdown]
# # 🐠 Unsupervised Clustering Experiment Workflow (Full Dataset)

# %% [markdown]
# This notebook contains the steps to run the clustering experiments on the whole dataset. The experiments cover different embedding methods (ResNet50, DINOv2), image processing (RGB, Grayscale), and embedding normalization, using various clustering algorithms.
#
# We will run the clustering algorithm first, save the results, and then immediately compute the **Adjusted Mutual Information (AMI)** score.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.3.3)
# Collecting argcomplete (from -r requirements.txt (line 2))
#   Downloading argcomplete-3.6.3-py3-none-any.whl.metadata (16 kB)
# Collecting scikit-learn (from -r requirements.txt (line 3))
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (4.67.1)
# Collecting regex (from -r requirements.txt (line 5))
#   Downloading regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.10.6)
# Collecting umap-learn (from -r requirements.txt (line 7))
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Collecting opencv-contrib-python (from -r requirements.txt (line 8))
#   Downloading opencv_contrib_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting opencv-python (from -r requirements.txt (line 9))
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting opencv-python-headless (from -r requirements.txt (line 10))
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting torch (from -r requirements.txt (line 11))
#   Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision (from -r requirements.txt (line 12))
#   Downloading torchvision-0.24.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting transformers (from -r requirements.txt (line 13))
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting timm (from -r requirements.txt (line 14))
#   Downloading timm-1.0.22-py3-none-any.whl.metadata (63 kB)
# Collecting joblib (from -r requirements.txt (line 15))
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting scipy>=1.10.0 (from scikit-learn->-r requirements.txt (line 3))
#   Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->-r requirements.txt (line 3))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 6)) (2.9.0.post0)
# Collecting numba>=0.51.2 (from umap-learn->-r requirements.txt (line 7))
#   Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting pynndescent>=0.5 (from umap-learn->-r requirements.txt (line 7))
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting numpy (from -r requirements.txt (line 1))
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting filelock (from torch->-r requirements.txt (line 11))
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (4.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (80.9.0)
# Collecting sympy>=1.13.3 (from torch->-r requirements.txt (line 11))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->-r requirements.txt (line 11))
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch->-r requirements.txt (line 11))
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch->-r requirements.txt (line 11))
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch->-r requirements.txt (line 11))
#   Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers->-r requirements.txt (line 13))
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 13)) (2.32.4)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->-r requirements.txt (line 13))
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers->-r requirements.txt (line 13))
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers->-r requirements.txt (line 13))
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.51.2->umap-learn->-r requirements.txt (line 7))
#   Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 6)) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->-r requirements.txt (line 11))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->transformers->-r requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->transformers->-r requirements.txt (line 13)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->transformers->-r requirements.txt (line 13)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->transformers->-r requirements.txt (line 13)) (2025.7.14)
# Downloading argcomplete-3.6.3-py3-none-any.whl (43 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 32.5 MB/s  0:00:00m0:00:01
# Downloading regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 11.0 MB/s  0:00:00
# Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
# Downloading opencv_contrib_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (73.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 MB 81.0 MB/s  0:00:006m0:00:010:01m
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 64.7 MB/s  0:00:006m0:00:01
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 128.2 MB/s  0:00:00m0:00:0100:01
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 117.3 MB/s  0:00:00m0:00:0100:01
# Downloading torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 98.9 MB/s  0:00:05m0:00:0100:01
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 139.3 MB/s  0:00:030:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 60.0 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 121.7 MB/s  0:00:00m0:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 11.6 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 127.6 MB/s  0:00:030:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 145.6 MB/s  0:00:010:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.7 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 151.3 MB/s  0:00:00m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 190.8 MB/s  0:00:010:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 171.8 MB/s  0:00:010:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 158.4 MB/s  0:00:010:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 153.6 MB/s  0:00:020:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 125.7 MB/s  0:00:00m0:00:01
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 163.2 MB/s  0:00:000:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 131.8 MB/s  0:00:010:00:0100:01
# Downloading torchvision-0.24.1-cp312-cp312-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 43.1 MB/s  0:00:00
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 59.8 MB/s  0:00:00
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 10.8 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.6 MB/s  0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 31.1 MB/s  0:00:00
# Downloading timm-1.0.22-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 31.3 MB/s  0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.1 MB/s  0:00:00
# Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 38.6 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 107.5 MB/s  0:00:00m0:00:0100:01
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 126.4 MB/s  0:00:00m0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 40.5 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 10.8 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, threadpoolctl, sympy, safetensors, regex, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, llvmlite, joblib, hf-xet, fsspec, filelock, argcomplete, scipy, opencv-python-headless, opencv-python, opencv-contrib-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, numba, huggingface-hub, tokenizers, scikit-learn, nvidia-cusolver-cu12, transformers, torch, pynndescent, umap-learn, torchvision, timm
#   Attempting uninstall: numpy1m╸━━━━━━━━━━━━━━━━━━━━━━━━━ 16/43 [nvidia-cublas-cu12]u12]
#     Found existing installation: numpy 2.3.3━━━━━━━━━━━━━━━━━━ 16/43 [nvidia-cublas-cu12]
#     Uninstalling numpy-2.3.3:91m╸━━━━━━━━━━━━━━━━━━━━━━━━ 17/43 [numpy]las-cu12]
#       Successfully uninstalled numpy-2.3.3━━━━━━━━━━━━━━━━━━━━━━━━ 17/43 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43/43 [timm]0m [timm]0m [torchvision]]er-cu12]]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyspark-client 4.0.1 requires googleapis-common-protos>=1.65.0, which is not installed.
# pyspark-client 4.0.1 requires grpcio>=1.67.0, which is not installed.
# pyspark-client 4.0.1 requires grpcio-status>=1.67.0, which is not installed.
# pyspark-client 4.0.1 requires pyarrow>=11.0.0, which is not installed.
# pyspark-connect 4.0.1 requires googleapis-common-protos>=1.65.0, which is not installed.
# pyspark-connect 4.0.1 requires grpcio>=1.67.0, which is not installed.
# pyspark-connect 4.0.1 requires grpcio-status>=1.67.0, which is not installed.
# pyspark-connect 4.0.1 requires pyarrow>=11.0.0, which is not installed.
# Successfully installed argcomplete-3.6.3 filelock-3.20.0 fsspec-2025.12.0 hf-xet-1.2.0 huggingface-hub-0.36.0 joblib-1.5.2 llvmlite-0.46.0 mpmath-1.3.0 networkx-3.6.1 numba-0.63.1 numpy-2.2.6 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 opencv-contrib-python-4.12.0.88 opencv-python-4.12.0.88 opencv-python-headless-4.12.0.88 pynndescent-0.5.13 regex-2025.11.3 safetensors-0.7.0 scikit-learn-1.8.0 scipy-1.16.3 sympy-1.14.0 threadpoolctl-3.6.0 timm-1.0.22 tokenizers-0.22.1 torch-2.9.1 torchvision-0.24.1 transformers-4.57.3 triton-3.5.1 umap-learn-0.5.9.post2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.40-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy<3,>=1.20 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (2.2.6)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn>=0.20->hdbscan) (3.6.0)
# Downloading hdbscan-0.8.40-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 20.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.40
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 1. Data Preparation and Embedding Extraction (Setup)

# %% [markdown]
# ### 1.1 Crop Images Around Bounding Boxes
#
# We are running the image cropping on both the training and test data folders, consolidating all results into the respective 'cropped' and 'cropped_test' directories.

# %%
# Training data
# !python3 crop_bbs.py --images_dir ../dataset/train --labels_dir ../dataset/train_labels --output_dir ../dataset/cropped --class_ids 1 2 3 4 5 6 7 8 9
# Test data
# !python3 crop_bbs.py --images_dir ../dataset/test --labels_dir ../dataset/test_labels --output_dir ../dataset/cropped_test --class_ids 1 2 3 4 5 6 7 8 9

# remember to grayscale the images

# %% [markdown]
# ### 1.2 Extract Embeddings for Training Data

# %%
# a) ResNet50 RGB
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped --output_file ../embeddings_files/resnet_embeddings.npz

# b) ResNet50 Grayscale
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_gray --output_file ../embeddings_files/resnet_embeddings_gray.npz

# c) DINOv2 RGB
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped --output_file ../embeddings_files/dino_embeddings.npz

# d) DINOv2 Grayscale
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_gray --output_file ../embeddings_files/dino_embeddings_gray.npz

# %% [markdown]
# ### 1.3 Extract Embeddings for Test Data

# %%
# a) ResNet50 RGB
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test --output_file ../embeddings_files/resnet_embeddings_test.npz

# b) ResNet50 Grayscale
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test_gray --output_file ../embeddings_files/resnet_embeddings_test_gray.npz

# c) DINOv2 RGB
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test --output_file ../embeddings_files/dino_embeddings_test.npz

# d) DINOv2 Grayscale
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test_gray --output_file ../embeddings_files/dino_embeddings_test_gray.npz

# %% [markdown]
# ### 1.4 Merge Embeddings and Normalise
#
# Merge all images (training and test) and then normalise the embeddings. Note: The merge command is symbolic as the actual command was not provided, but it's noted here for context.

# %%
# !!merging all images and merging the files in merging.npz with filenames in there

# a) ResNet50 RGB Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/resnet_embeddings.npz --output_file ../normalised_embeddings/resnet_normalised_embeddings.npz

# b) ResNet50 Grayscale Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/resnet_embeddings_gray.npz --output_file ../normalised_embeddings/resnet_normalised_embeddings_gray.npz

# c) DINOv2 RGB Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/dino_embeddings.npz --output_file ../normalised_embeddings/dino_normalised_embeddings.npz

# d) DINOv2 Grayscale Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/dino_embeddings_gray.npz --output_file ../normalised_embeddings/dino_embeddings_gray.npz

# %% [markdown]
# ***

# %% [markdown]
# ## 2. K-means Clustering and AMI Score

# %% [markdown]
# ### 2.1 K-means (Not Normalised)

# %% [markdown]
# i) resnet50, rgb, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_rgb_median_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_rgb_median_mahala.npz
# --> 0.1976
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_rgb_median_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29319
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29319
#
# ✅ Adjusted Mutual Information (AMI): 0.2841

# %% [markdown]
# ii) resnet50, grayscale, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_gray_median_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_gray_median_mahala.npz
# --> 0.2214
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_gray_median_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28236
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28236
#
# ✅ Adjusted Mutual Information (AMI): 0.3305

# %% [markdown]
# iii) DINOv2 rgb, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_rgb_median_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_rgb_median_mahala.npz
# --> 0.2756
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_rgb_median_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29019
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29019
#
# ✅ Adjusted Mutual Information (AMI): 0.3923

# %% [markdown]
# iv) DINOv2 gray, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_gray_median_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_gray_median_mahala.npz
# --> 0.2430
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_gray_median_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25758
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25758
#
# ✅ Adjusted Mutual Information (AMI): 0.5082

# %% [markdown]
# ### 2.2 K-means (Normalised)

# %% [markdown]
# i) resnet 50, rgb, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_rgb_normalised_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_rgb_normalised_mahala.npz

# --> 0.1886
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_rgb_normalised_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29333
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29333
#
# ✅ Adjusted Mutual Information (AMI): 0.2616

# %% [markdown]
# ii) resnet50, grayscale, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_gray_normalised_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_gray_normalised_mahala.npz
# --> 0.2099
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_gray_normalised_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28230
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28230
#
# ✅ Adjusted Mutual Information (AMI): 0.3723

# %% [markdown]
# iii) DINOv2, rgb, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_rgb_normalised_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_rgb_normalised_mahala.npz
# --> 0.2531
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_rgb_normalised_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29007
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29007
#
# ✅ Adjusted Mutual Information (AMI): 0.4029

# %% [markdown]
# iv) dinov2, grayscale, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_gray_normalised_mahala.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_gray_normalised_mahala.npz
# --> 0.2435
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_gray_normalised_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25745
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25745
#
# ✅ Adjusted Mutual Information (AMI): 0.4829

# %% [markdown]
# ***

# %% [markdown]
# ## 3. Agglomerative Clustering and AMI Score

# %% [markdown]
# ### 3.1 Agglomerative Clustering (Not Normalised)

# %% [markdown]
# i) Resnet 50 rgb, not normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/agglomerative_clusters_resnet_rgb.npz
# !python3 ami.py --clustered_file ../mahala_clusters/agglomerative_clusters_resnet_rgb.npz
# --> 0.2221
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/agglomerative_clusters_resnet_rgb.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29319
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29319
#
# ✅ Adjusted Mutual Information (AMI): 0.0191

# %% [markdown]
# ii) resnet50, grayscale, not normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/agglomerative_clusters_resnet_gray.npz
# !python3 ami.py --clustered_file ../mahala_clusters/agglomerative_clusters_resnet_gray.npz
# --> 0.2243
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/agglomerative_clusters_resnet_gray.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28236
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28236
#
# ✅ Adjusted Mutual Information (AMI): 0.0948

# %% [markdown]
# iii) DINOv2 rgb, nor normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/agglomerative_clusters_dino_rgb.npz
# !python3 ami.py --clustered_file ../mahala_clusters/agglomerative_clusters_dino_rgb.npz
# --> 0.2898
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/agglomerative_clusters_dino_rgb.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29019
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29019
#
# ✅ Adjusted Mutual Information (AMI): 0.2011

# %% [markdown]
# iv) DINOv2 grayscale, not normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/agglomerative_clusters_dino_gray.npz
# !python3 ami.py --clustered_file ../mahala_clusters/agglomerative_clusters_dino_gray.npz
# --> 0.2916
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/agglomerative_clusters_dino_gray.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25758
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25758
#
# ✅ Adjusted Mutual Information (AMI): 0.0533

# %% [markdown]
# ### 3.2 Agglomerative Clustering (Normalised)

# %% [markdown]
# i) resnet 50, rgb, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/ac_resnet_rgb_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/ac_resnet_rgb_normalised.npz
# --> 0.2165
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/ac_resnet_rgb_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29333
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29333
#
# ✅ Adjusted Mutual Information (AMI): 0.0365

# %% [markdown]
# ii) resnet50, gray, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/ac_resnet_gray_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/ac_resnet_gray_normalised.npz
# --> 0.2480
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/ac_resnet_gray_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28230
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28230
#
# ✅ Adjusted Mutual Information (AMI): 0.0058

# %% [markdown]
# iii) DINOv2, rgb, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/ac_dino_rgb_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/ac_dino_rgb_normalised.npz
# --> 0.3267
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/ac_dino_rgb_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29007
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29007
#
# ✅ Adjusted Mutual Information (AMI): 0.0177

# %% [markdown]
# iv) DINOv2, gray, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_clusters/ac_dino_gray_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/ac_dino_gray_normalised.npz
# --> 0.2556
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../mahala_clusters/ac_dino_gray_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25745
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25745
#
# ✅ Adjusted Mutual Information (AMI): 0.0101

# %% [markdown]
# ***

# %% [markdown]
# ## 4. HDBSCAN Clustering and AMI Score

# %% [markdown]
# ### 4.1 HDBSCAN (Not Normalised)

# %% [markdown]
# i) resnet 50, rgb, not normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_resnet_rgb.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_resnet_rgb.npz
# --> 0.0013
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_resnet_rgb.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29319
#    Cluster noise (-1):     119
#    Invalid ground truths:  0
#    Used in AMI:            29200
#
# ✅ Adjusted Mutual Information (AMI): 0.0038

# %% [markdown]
# ii) resnet50, grayscale, not normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_resnet_gray.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_resnet_gray.npz
# --> 0.0005
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_resnet_gray.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28236
#    Cluster noise (-1):     862
#    Invalid ground truths:  0
#    Used in AMI:            27374
#
# ✅ Adjusted Mutual Information (AMI): 0.0285

# %% [markdown]
# iii) DINOv2 rgb, nor normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_dino_rgb.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_dino_rgb.npz
# --> 0.3080
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_dino_rgb.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29019
#    Cluster noise (-1):     187
#    Invalid ground truths:  0
#    Used in AMI:            28832
#
# ✅ Adjusted Mutual Information (AMI): 0.0046

# %% [markdown]
# iv) DINOv2, grayscale, not normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_dino_gray.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_dino_gray.npz
# --> 0.3038
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_dino_gray.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25758
#    Cluster noise (-1):     15497
#    Invalid ground truths:  0
#    Used in AMI:            10261
#
# ✅ Adjusted Mutual Information (AMI): 0.3152

# %% [markdown]
# ### 4.2 HDBSCAN (Normalised)

# %% [markdown]
# i) resnet 50, rgb, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_resnet_rgb_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_resnet_rgb_normalised.npz
# --> 0.0013
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_resnet_rgb_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29333
#    Cluster noise (-1):     68
#    Invalid ground truths:  0
#    Used in AMI:            29265
#
# ✅ Adjusted Mutual Information (AMI): 0.0038

# %% [markdown]
# ii) resnet50, gray, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_resnet_gray_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_resnet_gray_normalised.npz
# --> 0.1129
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_resnet_gray_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28230
#    Cluster noise (-1):     3084
#    Invalid ground truths:  0
#    Used in AMI:            25146
#
# ✅ Adjusted Mutual Information (AMI): 0.1017

# %% [markdown]
# iii) DINOv2, rgb, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_norm_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_dino_rgb_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_dino_rgb_normalised.npz
# --> 0.3045
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_dino_rgb_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29007
#    Cluster noise (-1):     177
#    Invalid ground truths:  0
#    Used in AMI:            28830
#
# ✅ Adjusted Mutual Information (AMI): 0.0046

# %% [markdown]
# iv) DINOv2, gray, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_clusters/hdbscan_dino_gray_normalised.npz
# !python3 ami.py --clustered_file ../mahala_clusters/hdbscan_dino_gray_normalised.npz
# --> 0.3026
# Out:
# 🔍 Running HDBSCAN clustering...
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../mahala_clusters/hdbscan_dino_gray_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25745
#    Cluster noise (-1):     15293
#    Invalid ground truths:  0
#    Used in AMI:            10452
#
# ✅ Adjusted Mutual Information (AMI): 0.3155

# %% [markdown]
# ***

# %% [markdown]
# # K- medoids

# %% [markdown]
# ## not normalised

# %% [markdown]
# resnet rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 29319 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29319
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29319
#
# ✅ Adjusted Mutual Information (AMI): 0.1789

# %% [markdown]
# resnet gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_gray_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_gray_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 28236 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28236
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28236
#
# ✅ Adjusted Mutual Information (AMI): 0.2708

# %% [markdown]
# dino rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 29019 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29019
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29019
#
# ✅ Adjusted Mutual Information (AMI): 0.3770

# %% [markdown]
# dino gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_gray_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_gray_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 25758 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25758
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25758
#
# ✅ Adjusted Mutual Information (AMI): 0.4038

# %% [markdown]
# ## normalised

# %% [markdown]
# resnet rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_norm_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_norm_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 29333 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_norm_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29333
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29333
#
# ✅ Adjusted Mutual Information (AMI): 0.1964

# %% [markdown]
# resnet gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_norm_gray_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_norm_gray_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 28230 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_norm_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28230
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28230
#
# ✅ Adjusted Mutual Information (AMI): 0.2226

# %% [markdown]
# dino rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_norm_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_norm_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 25849 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_norm_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25849
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25849
#
# ✅ Adjusted Mutual Information (AMI): 0.4166

# %% [markdown]
# dino gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_norm_gray_mahala.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_norm_gray_mahala.npz
# Out:
# 🔍 Running K-Medoids clustering on 25745 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_norm_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25745
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25745
#
# ✅ Adjusted Mutual Information (AMI): 0.3136

# %% [markdown]
# # 5. UMAP + K-means Clustering and AMI Score

# %% [markdown]
# ### 5.1 UMAP + K-means (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_resnet_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_resnet_rgb_mahala.npz
# --> 0.2477
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_resnet_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29319
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29319
#
# ✅ Adjusted Mutual Information (AMI): 0.4326

# %% [markdown]
# ii) resnet grayscale, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_resnet_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_resnet_gray_mahala.npz
# --> 0.2931
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_resnet_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28236
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28236
#
# ✅ Adjusted Mutual Information (AMI): 0.4453

# %% [markdown]
# iii) dino, rgb, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_dino_rgb_median_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_dino_rgb_median_mahala.npz
# --> 0.3986
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_dino_rgb_median_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29019
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29019
#
# ✅ Adjusted Mutual Information (AMI): 0.5755

# %% [markdown]
# iv) dino, gray, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_dino_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_dino_gray_mahala.npz
# --> 0.3654
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_dino_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25758
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25758
#
# ✅ Adjusted Mutual Information (AMI): 0.5654

# %% [markdown]
# ### 5.2 UMAP + K-means (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_resnet_normalised_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_resnet_normalised_rgb_mahala.npz
# --> 0.2892
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_resnet_normalised_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29333
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29333
#
# ✅ Adjusted Mutual Information (AMI): 0.3840

# %% [markdown]
# ii) resnet grayscale, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_resnet_normalised_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_resnet_normalised_gray_mahala.npz
# --> 0.3088
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_resnet_normalised_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28230
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28230
#
# ✅ Adjusted Mutual Information (AMI): 0.4961

# %% [markdown]
# iii) dino, rgb, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_dino_normalised_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_dino_normalised_rgb_mahala.npz
# --> 0.4107
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_dino_normalised_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29007
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29007
#
# ✅ Adjusted Mutual Information (AMI): 0.5295

# %% [markdown]
# iv) dino, gray, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_km_dino_normalised_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_km_dino_normalised_gray_mahala.npz
# --> 0.3739
# Out:
# ✅ Saved clustered data to ../mahala_umap/umap_km_dino_normalised_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25745
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25745
#
# ✅ Adjusted Mutual Information (AMI): 0.4600

# %% [markdown]
# ***

# %% [markdown]
# ## 6. UMAP + Agglomerative Clustering and AMI Score

# %% [markdown]
# ### 6.1 UMAP + Agglomerative Clustering (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_resnet_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_resnet_rgb_mahala.npz
# --> 0.2516
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_resnet_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29319
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29319
#
# ✅ Adjusted Mutual Information (AMI): 0.0581

# %% [markdown]
# ii) resnet grayscale, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_resnet_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_resnet_gray_mahala.npz
# --> 0.3055
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_resnet_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28236
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28236
#
# ✅ Adjusted Mutual Information (AMI): 0.6229

# %% [markdown]
# iii) dino, rgb, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_dino_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_dino_rgb_mahala.npz
# --> 0.3765
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_dino_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29019
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29019
#
# ✅ Adjusted Mutual Information (AMI): 0.0872

# %% [markdown]
# iv) dino, gray, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_dino_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_dino_gray_mahala.npz
# --> 0.3441
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_dino_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25758
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25758
#
# ✅ Adjusted Mutual Information (AMI): 0.6576

# %% [markdown]
# ### 6.2 UMAP + Agglomerative Clustering (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_resnet_normalised_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_resnet_normalised_rgb_mahala.npz
# --> 0.2799
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_resnet_normalised_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29333
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29333
#
# ✅ Adjusted Mutual Information (AMI): 0.0312

# %% [markdown]
# ii) resnet grayscale, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_resnet_normalised_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_resnet_normalised_gray_mahala.npz
# --> 0.3116
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_resnet_normalised_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          28230
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            28230
#
# ✅ Adjusted Mutual Information (AMI): 0.0319

# %% [markdown]
# iii) dino, rgb, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_norm_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_dino_normalised_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_dino_normalised_rgb_mahala.npz
# --> 0.3895
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_dino_normalised_rgb_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          29007
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            29007
#
# ✅ Adjusted Mutual Information (AMI): 0.0241

# %% [markdown]
# iv) dino, gray, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --n_clusters 9 --output_file ../mahala_umap/umap_ac_dino_normalised_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_ac_dino_normalised_gray_mahala.npz
# --> 0.3424
# Out:
# /opt/conda/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved clustered data to ../mahala_umap/umap_ac_dino_normalised_gray_mahala.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25745
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25745
#
# ✅ Adjusted Mutual Information (AMI): 0.0294

# %% [markdown]
# ***

# %% [markdown]
# ## 7. UMAP + HDBSCAN Clustering and AMI Score

# %% [markdown]
# ### 7.1 UMAP + HDBSCAN (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_embeddings_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_resnet_rgb_mahala.npz
# Out:
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 40, in <module>
#     main()
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 32, in main
#     cluster_labels = clusterer.fit_predict(reduced_embeddings)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/hdbscan_.py", line 1312, in fit_predict
#     self.fit(X)
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/hdbscan_.py", line 1232, in fit
#     X = check_array(X, accept_sparse="csr", force_all_finite=False)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: check_array() got an unexpected keyword argument 'force_all_finite'

# %%
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_resnet_rgb_mahala.npz
# --> 0.2228

# %% [markdown]
# ii) resnet grayscale, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_resnet_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_resnet_gray_mahala.npz
# --> 0.2087
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 40, in <module>
#     main()
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 28, in main
#     reduced_embeddings = reducer.fit_transform(embeddings)
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_resnet_gray_mahala.npz'

# %% [markdown]
# iii) dino, rgb, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_embeddings_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_dino_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_dino_rgb_mahala.npz
# --> 0.2356
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 1, in <module>
#     import hdbscan
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/__init__.py", line 1, in <module>
#     from .hdbscan_ import HDBSCAN, hdbscan
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/hdbscan_.py", line 7, in <module>
#     import numpy as np
#   File "/opt/conda/lib/python3.12/site-packages/numpy/__init__.py", line 181, in <module>
#     from . import lib
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/__init__.py", line 23, in <module>
#     from . import _index_tricks_impl
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_index_tricks_impl.py", line 12, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/opt/conda/lib/python3.12/site-packages/numpy/matrixlib/__init__.py", line 4, in <module>
#     from . import defmatrix
#   File "/opt/conda/lib/python3.12/site-packages/numpy/matrixlib/defmatrix.py", line 12, in <module>
#     from numpy.linalg import matrix_power
#   File "/opt/conda/lib/python3.12/site-packages/numpy/linalg/__init__.py", line 88, in <module>
#     from . import _linalg
#   File "/opt/conda/lib/python3.12/site-packages/numpy/linalg/_linalg.py", line 41, in <module>
#     from numpy._typing import NDArray
#   File "/opt/conda/lib/python3.12/site-packages/numpy/_typing/__init__.py", line 102, in <module>
#     from ._dtype_like import (
#   File "/opt/conda/lib/python3.12/site-packages/numpy/_typing/_dtype_like.py", line 147, in <module>
#     type[np.unsignedinteger[Any]]
#   File "/opt/conda/lib/python3.12/typing.py", line 1289, in __or__
#     return Union[self, right]
#            ~~~~~^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 395, in inner
#     return _caches[func](*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 517, in __getitem__
#     return self._getitem(self, parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 736, in Union
#     return _UnionGenericAlias(self, parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 1275, in __init__
#     self.__parameters__ = _collect_parameters(args)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 289, in _collect_parameters
#     for x in getattr(t, '__parameters__', ()):
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_dino_rgb_mahala.npz'

# %% [markdown]
# iv) dino, gray, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_dino_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_dino_gray_mahala.npz
# --> 0.2296
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 40, in <module>
#     main()
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 28, in main
#     reduced_embeddings = reducer.fit_transform(embeddings)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/umap/umap_.py", line 2935, in fit_transform
#     self.fit(X, y, ensure_all_finite, **kwargs)
#   File "/opt/conda/lib/python3.12/site-packages/umap/umap_.py", line 2635, in fit
#     ) = nearest_neighbors(
#         ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/umap/umap_.py", line 330, in nearest_neighbors
#     knn_search_index = NNDescent(
#                        ^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/pynndescent_.py", line 806, in __init__
#     leaf_array = rptree_leaf_array(self._rp_forest)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/rp_trees.py", line 1436, in rptree_leaf_array
#     return np.vstack(rptree_leaf_array_parallel(rp_forest))
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/rp_trees.py", line 1428, in rptree_leaf_array_parallel
#     result = joblib.Parallel(n_jobs=-1, require="sharedmem")(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/joblib/parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/joblib/parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "/opt/conda/lib/python3.12/site-packages/joblib/parallel.py", line 1800, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_dino_gray_mahala.npz'

# %% [markdown]
# ### 7.2 UMAP + HDBSCAN (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_norm_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_resnet_normalised_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_resnet_normalised_rgb_mahala.npz
# --> 0.2260
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 1, in <module>
#     import hdbscan
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/__init__.py", line 1, in <module>
#     from .hdbscan_ import HDBSCAN, hdbscan
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/hdbscan_.py", line 7, in <module>
#     import numpy as np
#   File "/opt/conda/lib/python3.12/site-packages/numpy/__init__.py", line 181, in <module>
#     from . import lib
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/__init__.py", line 23, in <module>
#     from . import _index_tricks_impl
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_index_tricks_impl.py", line 12, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/opt/conda/lib/python3.12/site-packages/numpy/matrixlib/__init__.py", line 4, in <module>
#     from . import defmatrix
#   File "/opt/conda/lib/python3.12/site-packages/numpy/matrixlib/defmatrix.py", line 12, in <module>
#     from numpy.linalg import matrix_power
#   File "/opt/conda/lib/python3.12/site-packages/numpy/linalg/__init__.py", line 88, in <module>
#     from . import _linalg
#   File "/opt/conda/lib/python3.12/site-packages/numpy/linalg/_linalg.py", line 41, in <module>
#     from numpy._typing import NDArray
#   File "/opt/conda/lib/python3.12/site-packages/numpy/_typing/__init__.py", line 120, in <module>
#     from ._array_like import (
#   File "/opt/conda/lib/python3.12/site-packages/numpy/_typing/_array_like.py", line 116, in <module>
#     _ArrayLikeFloat_co: TypeAlias = _DualArrayLike[
#                                     ^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 395, in inner
#     return _caches[func](*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 1321, in __getitem__
#     args = _unpack_args(args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 314, in _unpack_args
#     newargs.append(arg)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_resnet_normalised_rgb_mahala.npz'

# %% [markdown]
# ii) resnet grayscale, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_norm_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_resnet_normalised_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_resnet_normalised_gray_mahala.npz
# --> 0.2136
# Out:
# ^C
# Exception ignored on calling ctypes callback function: <function ExecutionEngine._raw_object_cache_notify at 0x7fee3d10ccc0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/llvmlite/binding/executionengine.py", line 178, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_resnet_normalised_gray_mahala.npz'

# %% [markdown]
# iii) dino, rgb, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_norm_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_dino_normalised_rgb_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_dino_normalised_rgb_mahala.npz
# --> 0.2321
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 2, in <module>
#     import umap
#   File "/opt/conda/lib/python3.12/site-packages/umap/__init__.py", line 2, in <module>
#     from .umap_ import UMAP
#   File "/opt/conda/lib/python3.12/site-packages/umap/umap_.py", line 48, in <module>
#     from pynndescent import NNDescent
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/__init__.py", line 5, in <module>
#     from .pynndescent_ import NNDescent, PyNNDescentTransformer
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/pynndescent_.py", line 22, in <module>
#     import pynndescent.sparse as sparse
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/sparse.py", line 11, in <module>
#     from pynndescent.distances import (
#   File "/opt/conda/lib/python3.12/site-packages/pynndescent/distances.py", line 585, in <module>
#     @numba.njit(
#      ^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/decorators.py", line 234, in wrapper
#     disp.compile(sig)
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/dispatcher.py", line 908, in compile
#     cres = self._compiler.compile(args, return_type)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/dispatcher.py", line 80, in compile
#     status, retval = self._compile_cached(args, return_type)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/dispatcher.py", line 94, in _compile_cached
#     retval = self._compile_core(args, return_type)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/dispatcher.py", line 107, in _compile_core
#     cres = compiler.compile_extra(self.targetdescr.typing_context,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler.py", line 739, in compile_extra
#     return pipeline.compile_extra(func)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler.py", line 439, in compile_extra
#     return self._compile_bytecode()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler.py", line 505, in _compile_bytecode
#     return self._compile_core()
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler.py", line 473, in _compile_core
#     pm.run(self.state)
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler_machinery.py", line 356, in run
#     self._runPass(idx, pass_inst, state)
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler_lock.py", line 35, in _acquire_compile_lock
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler_machinery.py", line 311, in _runPass
#     mutated |= check(pss.run_pass, internal_state)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/compiler_machinery.py", line 272, in check
#     mangled = func(compiler_state)
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/typed_passes.py", line 564, in run_pass
#     check_and_legalize_ir(state.func_ir, flags=state.flags)
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/ir_utils.py", line 2280, in check_and_legalize_ir
#     post_proc.run(True, extend_lifetimes=flags.dbg_extend_lifetimes)
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/postproc.py", line 84, in run
#     vlt.usedefs.defmap,
#     ^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/functools.py", line 998, in __get__
#     val = self.func(instance)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/postproc.py", line 44, in usedefs
#     return analysis.compute_use_defs(self._blocks)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/analysis.py", line 40, in compute_use_defs
#     rhs_set = set(var.name for var in stmt.value.list_vars())
#                                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/ir.py", line 612, in list_vars
#     return self._rec_list_vars(self._kws)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/ir.py", line 337, in _rec_list_vars
#     lst.extend(self._rec_list_vars(v))
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numba/core/ir.py", line 321, in _rec_list_vars
#     def _rec_list_vars(self, val):
#
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_dino_normalised_rgb_mahala.npz'

# %% [markdown]
# iv) dino, gray, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_norm_gray_median_mahalanobis.npz --min_cluster_size 10 --output_file ../mahala_umap/umap_hdbscan_dino_normalised_gray_mahala.npz
# !python3 ami.py --clustered_file ../mahala_umap/umap_hdbscan_dino_normalised_gray_mahala.npz
# --> 0.2282
# Out:
# ^C
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/umap_hdbscan.py", line 1, in <module>
#     import hdbscan
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/__init__.py", line 1, in <module>
#     from .hdbscan_ import HDBSCAN, hdbscan
#   File "/opt/conda/lib/python3.12/site-packages/hdbscan/hdbscan_.py", line 7, in <module>
#     import numpy as np
#   File "/opt/conda/lib/python3.12/site-packages/numpy/__init__.py", line 181, in <module>
#     from . import lib
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/__init__.py", line 23, in <module>
#     from . import _index_tricks_impl
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_index_tricks_impl.py", line 12, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/opt/conda/lib/python3.12/site-packages/numpy/matrixlib/__init__.py", line 4, in <module>
#     from . import defmatrix
#   File "/opt/conda/lib/python3.12/site-packages/numpy/matrixlib/defmatrix.py", line 12, in <module>
#     from numpy.linalg import matrix_power
#   File "/opt/conda/lib/python3.12/site-packages/numpy/linalg/__init__.py", line 88, in <module>
#     from . import _linalg
#   File "/opt/conda/lib/python3.12/site-packages/numpy/linalg/_linalg.py", line 41, in <module>
#     from numpy._typing import NDArray
#   File "/opt/conda/lib/python3.12/site-packages/numpy/_typing/__init__.py", line 102, in <module>
#     from ._dtype_like import (
#   File "/opt/conda/lib/python3.12/site-packages/numpy/_typing/_dtype_like.py", line 244, in <module>
#     _DTypeLikeBool
#   File "/opt/conda/lib/python3.12/typing.py", line 1289, in __or__
#     return Union[self, right]
#            ~~~~~^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 395, in inner
#     return _caches[func](*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 517, in __getitem__
#     return self._getitem(self, parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 736, in Union
#     return _UnionGenericAlias(self, parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 1275, in __init__
#     self.__parameters__ = _collect_parameters(args)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/typing.py", line 285, in _collect_parameters
#     elif hasattr(t, '__typing_subst__'):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/work/Ursula/scripts/ami.py", line 71, in <module>
#     main()
#   File "/work/Ursula/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../mahala_umap/umap_hdbscan_dino_normalised_gray_mahala.npz'
