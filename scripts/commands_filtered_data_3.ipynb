# %% [markdown]
# # 🐠 Unsupervised Clustering Experiment Workflow (Full Dataset)

# %% [markdown]
# This notebook contains the steps to run the clustering experiments on the whole dataset. The experiments cover different embedding methods (ResNet50, DINOv2), image processing (RGB, Grayscale), and embedding normalization, using various clustering algorithms.
#
# We will run the clustering algorithm first, save the results, and then immediately compute the **Adjusted Mutual Information (AMI)** score.

# %% [markdown]
# ## 1. Data Preparation and Embedding Extraction (Setup)

# %% [markdown]
# ### 1.1 Crop Images Around Bounding Boxes
#
# We are running the image cropping on both the training and test data folders, consolidating all results into the respective 'cropped' and 'cropped_test' directories.

# %%
# Training data
# !python3 crop_bbs.py --images_dir ../dataset/train --labels_dir ../dataset/train_labels --output_dir ../dataset/cropped --class_ids 1 2 3 4 5 6 7 8 9
# Test data
# !python3 crop_bbs.py --images_dir ../dataset/test --labels_dir ../dataset/test_labels --output_dir ../dataset/cropped_test --class_ids 1 2 3 4 5 6 7 8 9

# remember to grayscale the images

# %% [markdown]
# ### 1.2 Extract Embeddings for Training Data

# %%
# a) ResNet50 RGB
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped --output_file ../embeddings_files/resnet_embeddings.npz

# b) ResNet50 Grayscale
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_gray --output_file ../embeddings_files/resnet_embeddings_gray.npz

# c) DINOv2 RGB
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped --output_file ../embeddings_files/dino_embeddings.npz

# d) DINOv2 Grayscale
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_gray --output_file ../embeddings_files/dino_embeddings_gray.npz

# %% [markdown]
# ### 1.3 Extract Embeddings for Test Data

# %%
# a) ResNet50 RGB
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test --output_file ../embeddings_files/resnet_embeddings_test.npz

# b) ResNet50 Grayscale
# !python3 extract_embeddings.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test_gray --output_file ../embeddings_files/resnet_embeddings_test_gray.npz

# c) DINOv2 RGB
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test --output_file ../embeddings_files/dino_embeddings_test.npz

# d) DINOv2 Grayscale
# !python3 extract_embeddings_dinov2.py --image_dir /Users/alteafogh/Documents/ITU/Research_project/Finding_A_Nemo/dataset/cropped/cropped_test_gray --output_file ../embeddings_files/dino_embeddings_test_gray.npz

# %% [markdown]
# ### 1.4 Merge Embeddings and Normalise
#
# Merge all images (training and test) and then normalise the embeddings. Note: The merge command is symbolic as the actual command was not provided, but it's noted here for context.

# %%
# !!merging all images and merging the files in merging.npz with filenames in there

# a) ResNet50 RGB Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/resnet_embeddings.npz --output_file ../normalised_embeddings/resnet_normalised_embeddings.npz

# b) ResNet50 Grayscale Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/resnet_embeddings_gray.npz --output_file ../normalised_embeddings/resnet_normalised_embeddings_gray.npz

# c) DINOv2 RGB Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/dino_embeddings.npz --output_file ../normalised_embeddings/dino_normalised_embeddings.npz

# d) DINOv2 Grayscale Normalisation
# !python3 embeddings_normaliser.py --input_file ../embeddings_files/dino_embeddings_gray.npz --output_file ../normalised_embeddings/dino_embeddings_gray.npz

# %% [markdown]
# ***

# %% [markdown]
# ## 2. K-means Clustering and AMI Score

# %% [markdown]
# ### 2.1 K-means (Not Normalised)

# %% [markdown]
# i) resnet50, rgb, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_rgb_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_rgb_median.npz
# --> 0.1976
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_rgb_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25094
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25094
#
# ✅ Adjusted Mutual Information (AMI): 0.3574

# %% [markdown]
# ii) resnet50, grayscale, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_gray_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_gray_median.npz
# --> 0.2214
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_gray_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25095
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25095
#
# ✅ Adjusted Mutual Information (AMI): 0.3884

# %% [markdown]
# iii) DINOv2 rgb, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../euclidean_filtered_embeddings/dino_embeddings_filtered_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_rgb_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_rgb_median.npz
# --> 0.2756
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_rgb_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25727
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25727
#
# ✅ Adjusted Mutual Information (AMI): 0.5190

# %% [markdown]
# iv) DINOv2 gray, not normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_gray_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_gray_median.npz
# --> 0.2430
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_gray_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          24615
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            24615
#
# ✅ Adjusted Mutual Information (AMI): 0.4861

# %% [markdown]
# ### 2.2 K-means (Normalised)

# %% [markdown]
# i) resnet 50, rgb, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_rgb_normalised_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_rgb_normalised_median.npz
# --> 0.1886
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_rgb_normalised_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25882
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25882
#
# ✅ Adjusted Mutual Information (AMI): 0.3017

# %% [markdown]
# ii) resnet50, grayscale, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_gray_normalised_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_gray_normalised_median.npz
# --> 0.2099
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_gray_normalised_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25358
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25358
#
# ✅ Adjusted Mutual Information (AMI): 0.3848

# %% [markdown]
# iii) DINOv2, rgb, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_rgb_normalised_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_rgb_normalised_median.npz
# --> 0.2531
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_rgb_normalised_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25849
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25849
#
# ✅ Adjusted Mutual Information (AMI): 0.4432

# %% [markdown]
# iv) dinov2, grayscale, normalised, 9 classes

# %%
# !python3 k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_gray_normalised_median.npz
# !python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_gray_normalised_median.npz
# --> 0.2435
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_dino_gray_normalised_median.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          24813
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            24813
#
# ✅ Adjusted Mutual Information (AMI): 0.4856

# %% [markdown]
# ***

# %% [markdown]
# ## 3. Agglomerative Clustering and AMI Score

# %% [markdown]
# ### 3.1 Agglomerative Clustering (Not Normalised)

# %% [markdown]
# i) Resnet 50 rgb, not normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --n_clusters 9 --output_file ../filtered_clusters/agglomerative_clusters_resnet_rgb.npz
# !python3 ami.py --clustered_file ../filtered_clusters/agglomerative_clusters_resnet_rgb.npz
# --> 0.2221
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/agglomerative_clusters_resnet_rgb.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25094
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25094
#
# ✅ Adjusted Mutual Information (AMI): 0.0764

# %% [markdown]
# ii) resnet50, grayscale, not normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --n_clusters 9 --output_file ../filtered_clusters/agglomerative_clusters_resnet_gray.npz
# !python3 ami.py --clustered_file ../filtered_clusters/agglomerative_clusters_resnet_gray.npz
# --> 0.2243
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/agglomerative_clusters_resnet_gray.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25095
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25095
#
# ✅ Adjusted Mutual Information (AMI): 0.0901

# %% [markdown]
# iii) DINOv2 rgb, nor normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --n_clusters 9 --output_file ../filtered_clusters/agglomerative_clusters_dino_rgb.npz
# !python3 ami.py --clustered_file ../filtered_clusters/agglomerative_clusters_dino_rgb.npz
# --> 0.2898
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/agglomerative_clusters_dino_rgb.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25727
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25727
#
# ✅ Adjusted Mutual Information (AMI): 0.7158

# %% [markdown]
# iv) DINOv2 grayscale, not normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --n_clusters 9 --output_file ../filtered_clusters/agglomerative_clusters_dino_gray.npz
# !python3 ami.py --clustered_file ../filtered_clusters/agglomerative_clusters_dino_gray.npz
# --> 0.2916
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/agglomerative_clusters_dino_gray.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          24615
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            24615
#
# ✅ Adjusted Mutual Information (AMI): 0.0563

# %% [markdown]
# ### 3.2 Agglomerative Clustering (Normalised)

# %% [markdown]
# i) resnet 50, rgb, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --n_clusters 9 --output_file ../filtered_clusters/ac_resnet_rgb_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/ac_resnet_rgb_normalised.npz
# --> 0.2165
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/ac_resnet_rgb_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25882
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25882
#
# ✅ Adjusted Mutual Information (AMI): 0.0514

# %% [markdown]
# ii) resnet50, gray, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../filtered_clusters/ac_resnet_gray_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/ac_resnet_gray_normalised.npz
# --> 0.2480
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/ac_resnet_gray_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25358
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25358
#
# ✅ Adjusted Mutual Information (AMI): 0.0106

# %% [markdown]
# iii) DINOv2, rgb, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --n_clusters 9 --output_file ../filtered_clusters/ac_dino_rgb_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/ac_dino_rgb_normalised.npz
# --> 0.3267
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/ac_dino_rgb_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25849
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25849
#
# ✅ Adjusted Mutual Information (AMI): 0.6484

# %% [markdown]
# iv) DINOv2, gray, normalised, 9 classes

# %%
# !python3 agglomerative_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../filtered_clusters/ac_dino_gray_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/ac_dino_gray_normalised.npz
# --> 0.2556
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../filtered_clusters/ac_dino_gray_normalised.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          24813
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            24813
#
# ✅ Adjusted Mutual Information (AMI): 0.0122

# %% [markdown]
# ***

# %% [markdown]
# ## 4. HDBSCAN Clustering and AMI Score

# %% [markdown]
# ### 4.1 HDBSCAN (Not Normalised)

# %% [markdown]
# i) resnet 50, rgb, not normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_resnet_rgb.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_resnet_rgb.npz
# --> 0.0013

# %% [markdown]
# ii) resnet50, grayscale, not normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_resnet_gray.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_resnet_gray.npz
# --> 0.0005
# Out:
# ^C
# Traceback (most recent call last):
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/hdbscan_clustering.py", line 3, in <module>
#     import hdbscan
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/hdbscan/__init__.py", line 1, in <module>
#     from .hdbscan_ import HDBSCAN, hdbscan
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/hdbscan/hdbscan_.py", line 9, in <module>
#     from sklearn.base import BaseEstimator, ClusterMixin
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/arrow/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow.accessors import (
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 982, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 925, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1423, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1395, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1526, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1569, in _fill_cache
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 71, in <module>
#     main()
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py", line 405, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../filtered_clusters/hdbscan_resnet_gray.npz'

# %% [markdown]
# iii) DINOv2 rgb, nor normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_dino_rgb.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_dino_rgb.npz
# --> 0.3080

# %% [markdown]
# iv) DINOv2, grayscale, not normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_dino_gray.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_dino_gray.npz
# --> 0.3038

# %% [markdown]
# ### 4.2 HDBSCAN (Normalised)

# %% [markdown]
# i) resnet 50, rgb, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_resnet_rgb_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_resnet_rgb_normalised.npz
# --> 0.0013

# %% [markdown]
# ii) resnet50, gray, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_gray.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_resnet_gray_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_resnet_gray_normalised.npz
# --> 0.1129

# %% [markdown]
# iii) DINOv2, rgb, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_dino_rgb_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters/hdbscan_dino_rgb_normalised.npz
# --> 0.3045

# %% [markdown]
# iv) DINOv2, gray, normalised, min_cluster_size 10

# %%
# !python3 hdbscan_clustering.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_norm_median.npz --min_cluster_size 10 --output_file ../filtered_clusters/hdbscan_dino_gray_normalised.npz
# !python3 ami.py --clustered_file ../filtered_clusters//hdbscan_dino_gray_normalised.npz
# --> 0.3026

# %% [markdown]
# ***

# %% [markdown]
# ## 5.0 K- medoids

# %% [markdown]
# ## Not normalised data
# ## euclidean

# %% [markdown]
# Resnet 50 rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_euclidean.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 25094 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25094
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25094
#
# ✅ Adjusted Mutual Information (AMI): 0.2877

# %% [markdown]
# resnet gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_gray_euclidean.npz 
# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_gray_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 25095 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_gray_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25095
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25095
#
# ✅ Adjusted Mutual Information (AMI): 0.3034

# %% [markdown]
# dino rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_euclidean.npz 


# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 25727 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25727
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25727
#
# ✅ Adjusted Mutual Information (AMI): 0.3843

# %% [markdown]
# dino gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_gray_euclidean.npz 


# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_gray_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 24615 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_gray_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          24615
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            24615
#
# ✅ Adjusted Mutual Information (AMI): 0.3507

# %% [markdown]
# ## normalised data

# %% [markdown]
#  resnet 50 rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_norm_euclidean.npz 


# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_norm_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 25882 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_norm_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25882
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25882
#
# ✅ Adjusted Mutual Information (AMI): 0.1903

# %% [markdown]
# resnet gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_resnet_gray_norm_euclidean.npz 


# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_resnet_gray_norm_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 25358 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_resnet_gray_norm_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25358
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25358
#
# ✅ Adjusted Mutual Information (AMI): 0.3058

# %% [markdown]
# dino rgb

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_norm_euclidean.npz 


# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_norm_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 25849 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_norm_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          25849
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            25849
#
# ✅ Adjusted Mutual Information (AMI): 0.4166

# %% [markdown]
# dino gray

# %%
# !python3 k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --n_clusters 9 --output_file ../k_medoids_clusters/k_medoids_dino_gray_norm_euclidean.npz 


# !python3 ami.py --clustered_file  ../k_medoids_clusters/k_medoids_dino_gray_norm_euclidean.npz
# Out:
# 🔍 Running K-Medoids clustering on 24615 samples...
#    Fitting K-Medoids with 9 clusters...
# ✅ Saved clustered data (embeddings, paths, labels) to ../k_medoids_clusters/k_medoids_dino_gray_norm_euclidean.npz
#
# 📊 AMI Calculation Summary:
#    Total samples:          24615
#    Cluster noise (-1):     0
#    Invalid ground truths:  0
#    Used in AMI:            24615
#
# ✅ Adjusted Mutual Information (AMI): 0.3507

# %% [markdown]
# ## 5. UMAP + K-means Clustering and AMI Score

# %% [markdown]
# ### 5.1 UMAP + K-means (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_resnet_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_resnet_rgb_eu.npz
# --> 0.2477

# %% [markdown]
# ii) resnet grayscale, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_resnet_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_resnet_gray_eu.npz
# --> 0.2931
# Out:
# The TensorFlow library was compiled to use AVX instructions, but these aren't available on your machine.
# ^C
# Traceback (most recent call last):
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 71, in <module>
#     main()
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py", line 405, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../euclidean_umap/umap_km_resnet_gray_eu.npz'

# %% [markdown]
# iii) dino, rgb, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_dino_rgb_median_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_dino_rgb_median_eu.npz
# --> 0.3986
# Out:
# The TensorFlow library was compiled to use AVX instructions, but these aren't available on your machine.
# ^C
# Traceback (most recent call last):
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 71, in <module>
#     main()
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py", line 405, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../umap_k_means_clusters/umap_km_dino_rgb_median.npz'

# %% [markdown]
# iv) dino, gray, not normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_dino_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_dino_gray_eu.npz
# --> 0.3654

# %% [markdown]
# ### 5.2 UMAP + K-means (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_resnet_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_resnet_normalised_rgb_eu.npz
# --> 0.2892

# %% [markdown]
# ii) resnet grayscale, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_resnet_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_resnet_normalised_gray_eu.npz
# --> 0.3088

# %% [markdown]
# iii) dino, rgb, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_dino_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_dino_normalised_rgb_eu.npz
# --> 0.4107

# %% [markdown]
# iv) dino, gray, normalised 9 classes

# %%
# !python3 umap_k_means.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_km_dino_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_km_dino_normalised_gray_eu.npz
# --> 0.3739

# %% [markdown]
# ***

# %% [markdown]
# ## 6. UMAP + Agglomerative Clustering and AMI Score

# %% [markdown]
# ### 6.1 UMAP + Agglomerative Clustering (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_resnet_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_resnet_rgb_eu.npz
# --> 0.2516

# %% [markdown]
# ii) resnet grayscale, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_resnet_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_resnet_gray_eu.npz
# --> 0.3055

# %% [markdown]
# iii) dino, rgb, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_dino_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_dino_rgb_eu.npz
# --> 0.3765

# %% [markdown]
# iv) dino, gray, not normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_dino_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_dino_gray_eu.npz
# --> 0.3441

# %% [markdown]
# ### 6.2 UMAP + Agglomerative Clustering (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_resnet_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_resnet_normalised_rgb_eu.npz
# --> 0.2799

# %% [markdown]
# ii) resnet grayscale, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_resnet_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_resnet_normalised_gray_eu.npz
# --> 0.3116

# %% [markdown]
# iii) dino, rgb, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_dino_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_dino_normalised_rgb_eu.npz
# --> 0.3895

# %% [markdown]
# iv) dino, gray, normalised 9 classes

# %%
# !python3 umap_ac.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_gray.npz --n_clusters 9 --output_file ../euclidean_umap/umap_ac_dino_normalised_gray.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_ac_dino_normalised_gray.npz
# --> 0.3424

# %% [markdown]
# ***

# %% [markdown]
# ## 7. UMAP + HDBSCAN Clustering and AMI Score

# %% [markdown]
# ### 7.1 UMAP + HDBSCAN (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_resnet_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_resnet_rgb_eu.npz
# Out:
# The TensorFlow library was compiled to use AVX instructions, but these aren't available on your machine.
# ^C

# %%
# --> 0.2228

# %% [markdown]
# ii) resnet grayscale, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_resnet_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_resnet_gray_eu.npz
# --> 0.2087

# %% [markdown]
# iii) dino, rgb, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_dino_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_dino_rgb_eu.npz
# --> 0.2356

# %% [markdown]
# iv) dino, gray, not normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_dino_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_dino_gray_eu.npz
# --> 0.2296

# %% [markdown]
# ### 7.2 UMAP + HDBSCAN (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_resnet_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_resnet_normalised_rgb_eu.npz
# --> 0.2260

# %% [markdown]
# ii) resnet grayscale, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_gray.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_resnet_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_resnet_normalised_gray_eu.npz
# --> 0.2136

# %% [markdown]
# iii) dino, rgb, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_dino_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_dino_normalised_rgb_eu.npz
# --> 0.2321

# %% [markdown]
# iv) dino, gray, normalised, min_cluster_size 10

# %%
# !python3 umap_hdbscan.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_norm_median.npz --min_cluster_size 10 --output_file ../euclidean_umap/umap_hdbscan_dino_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_hdbscan_dino_normalised_gray_eu.npz
# --> 0.2282

# %% [markdown]
# ## 8. UMAP + K-MEDOIDS clustering and ami score

# %% [markdown]
# ### 7.1 UMAP + K medoids (Not Normalised)

# %% [markdown]
# i) resnet, rgb, not normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_median.npz --output_file ../euclidean_umap/umap_kmedoids_resnet_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_resnet_rgb_eu.npz
# Out:
# The TensorFlow library was compiled to use AVX instructions, but these aren't available on your machine.
# ^C
# Traceback (most recent call last):
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 71, in <module>
#     main()
#   File "/Users/alteafogh/Documents/ITU/aau_work/Ariel2/scripts/ami.py", line 55, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#   File "/Users/alteafogh/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py", line 405, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '../euclidean_umap/umap_kmedoids_resnet_rgb_eu.npz'

# %% [markdown]
# ii) resnet grayscale, not normalised

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_gray_median.npz --output_file ../euclidean_umap/umap_kmedoids_resnet_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_resnet_gray_eu.npz

# %% [markdown]
# iii) dino, rgb, not normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_median.npz --output_file ../euclidean_umap/umap_kmedoids_dino_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_dino_rgb_eu.npz
# Out:
# The TensorFlow library was compiled to use AVX instructions, but these aren't available on your machine.

# %% [markdown]
# iv) dino, gray, not normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_median.npz --output_file ../euclidean_umap/umap_kmedoids_dino_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_dino_gray_eu.npz

# %% [markdown]
# ### 7.2 UMAP + K medoids (Normalised)

# %% [markdown]
# i) resnet, rgb, normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/resnet_embeddings_norm_median.npz --output_file ../euclidean_umap/umap_kmedoids_resnet_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_resnet_normalised_rgb_eu.npz

# %% [markdown]
# ii) resnet grayscale, normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_gray.npz --output_file ../euclidean_umap/umap_kmedoids_resnet_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_resnet_normalised_gray_eu.npz

# %% [markdown]
# iii) dino, rgb, normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_norm_median.npz --output_file ../euclidean_umap/umap_kmedoids_dino_normalised_rgb_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_dino_normalised_rgb_eu.npz

# %% [markdown]
# iv) dino, gray, normalised,

# %%
# !python3 umap_k_medoids.py --embedding_file ../embeddings_filtered/dino_embeddings_gray_norm_median.npz --output_file ../euclidean_umap/umap_kmedoids_dino_normalised_gray_eu.npz
# !python3 ami.py --clustered_file ../euclidean_umap/umap_kmedoids_dino_normalised_gray_eu.npz
