# %%
# !pip install hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.40-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy<3,>=1.20 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.12/site-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn>=0.20->hdbscan) (3.6.0)
# Downloading hdbscan-0.8.40-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 32.7 MB/s  0:00:00
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.40

# %%
# !pip install -r req.txt
# Out:
# Collecting argcomplete==3.2.2 (from -r req.txt (line 1))
#   Downloading argcomplete-3.2.2-py3-none-any.whl.metadata (16 kB)
# Collecting certifi==2025.8.3 (from -r req.txt (line 2))
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset-normalizer==3.4.3 (from -r req.txt (line 3))
#   Downloading charset_normalizer-3.4.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# Collecting contourpy==1.3.0 (from -r req.txt (line 4))
#   Downloading contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler==0.12.1 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 5)) (0.12.1)
# Collecting filelock==3.19.1 (from -r req.txt (line 6))
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: fonttools==4.59.2 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 7)) (4.59.2)
# Collecting fsspec==2025.9.0 (from -r req.txt (line 8))
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna==3.10 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 11)) (3.10)
# Collecting imageio==2.37.0 (from -r req.txt (line 12))
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting importlib_resources==6.5.2 (from -r req.txt (line 13))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: Jinja2==3.1.6 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 14)) (3.1.6)
# Collecting joblib==1.4.2 (from -r req.txt (line 15))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting kiwisolver==1.4.7 (from -r req.txt (line 16))
#   Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting lazy_loader==0.4 (from -r req.txt (line 17))
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting llvmlite==0.43.0 (from -r req.txt (line 18))
#   Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: MarkupSafe==3.0.2 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 19)) (3.0.2)
# Collecting matplotlib==3.9.2 (from -r req.txt (line 20))
#   Downloading matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting mpmath==1.3.0 (from -r req.txt (line 21))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting narwhals==2.7.0 (from -r req.txt (line 22))
#   Downloading narwhals-2.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting networkx==3.2.1 (from -r req.txt (line 23))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting numba==0.60.0 (from -r req.txt (line 24))
#   Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting numpy==1.26.4 (from -r req.txt (line 25))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting opencv-contrib-python==4.6.0.66 (from -r req.txt (line 26))
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting opencv-python==4.8.0.74 (from -r req.txt (line 27))
#   Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting opencv-python-headless==4.6.0.66 (from -r req.txt (line 28))
#   Downloading opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: packaging==25.0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 29)) (25.0)
# Collecting pandas==2.3.3 (from -r req.txt (line 30))
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: pillow==11.3.0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 31)) (11.3.0)
# Collecting plotly==6.3.1 (from -r req.txt (line 32))
#   Downloading plotly-6.3.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting pynndescent==0.5.13 (from -r req.txt (line 33))
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting pyparsing==3.0.9 (from -r req.txt (line 34))
#   Downloading pyparsing-3.0.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 35)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 36)) (2025.2)
# Requirement already satisfied: PyYAML==6.0.2 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 37)) (6.0.2)
# Collecting regex==2023.12.25 (from -r req.txt (line 38))
#   Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests==2.32.5 (from -r req.txt (line 39))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting scikit-image==0.24.0 (from -r req.txt (line 41))
#   Downloading scikit_image-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting scikit-learn==1.6.1 (from -r req.txt (line 42))
#   Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scipy==1.13.1 (from -r req.txt (line 43))
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting seaborn==0.13.2 (from -r req.txt (line 44))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: six==1.17.0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 45)) (1.17.0)
# Collecting sympy==1.14.0 (from -r req.txt (line 46))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting threadpoolctl==3.6.0 (from -r req.txt (line 47))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting tifffile==2024.8.30 (from -r req.txt (line 48))
#   Downloading tifffile-2024.8.30-py3-none-any.whl.metadata (31 kB)
# Collecting torch==2.2.2 (from -r req.txt (line 51))
#   Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torchvision==0.17.2 (from -r req.txt (line 52))
#   Downloading torchvision-0.17.2-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm==4.65.0 (from -r req.txt (line 53))
#   Downloading tqdm-4.65.0-py3-none-any.whl.metadata (56 kB)
# Requirement already satisfied: typing_extensions==4.15.0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 55)) (4.15.0)
# Requirement already satisfied: tzdata==2025.2 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 56)) (2025.2)
# Collecting umap-learn==0.5.9.post2 (from -r req.txt (line 57))
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: urllib3==2.5.0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 58)) (2.5.0)
# Requirement already satisfied: zipp==3.23.0 in /opt/conda/lib/python3.12/site-packages (from -r req.txt (line 59)) (3.23.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2->-r req.txt (line 51))
#   Downloading nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Downloading argcomplete-3.2.2-py3-none-any.whl (42 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading charset_normalizer-3.4.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (151 kB)
# Downloading contourpy-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.2 MB/s  0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading llvmlite-0.43.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 16.3 MB/s  0:00:02m0:00:0100:01
# Downloading matplotlib-3.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 46.2 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 5.4 MB/s  0:00:00
# Downloading narwhals-2.7.0-py3-none-any.whl (412 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.5 MB/s  0:00:00
# Downloading numba-0.60.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 13.1 MB/s  0:00:00m0:00:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 65.0 MB/s  0:00:006m0:00:01
# Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 22.1 MB/s  0:00:03m0:00:0100:01
# Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 130.6 MB/s  0:00:00m0:00:0100:01
# Downloading opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 MB 43.9 MB/s  0:00:01m0:00:0100:01m
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 59.5 MB/s  0:00:006m0:00:01
# Downloading plotly-6.3.1-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 54.5 MB/s  0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (789 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.1/789.1 kB 9.7 MB/s  0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading scikit_image-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 80.1 MB/s  0:00:00
# Downloading scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 85.1 MB/s  0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 81.7 MB/s  0:00:006m0:00:010:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 42.1 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
# Downloading torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 9.7 MB/s  0:01:116m0:00:0100:03
# Downloading torchvision-0.17.2-cp312-cp312-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 7.7 MB/s  0:00:006m0:00:0100:01
# Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
# Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 101.7 MB/s  0:00:030:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.9 MB/s  0:00:006m0:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 91.8 MB/s  0:00:006m0:00:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 5.8 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 67.2 MB/s  0:00:06m0:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 79.8 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 73.7 MB/s  0:00:006m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 104.7 MB/s  0:00:010:00:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 87.9 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 92.4 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 57.5 MB/s  0:00:006m0:00:010:01
# Installing collected packages: mpmath, tqdm, threadpoolctl, sympy, regex, pyparsing, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, narwhals, llvmlite, lazy_loader, kiwisolver, joblib, importlib_resources, fsspec, filelock, charset-normalizer, certifi, argcomplete, tifffile, scipy, requests, plotly, pandas, opencv-python-headless, opencv-python, opencv-contrib-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numba, imageio, contourpy, scikit-learn, scikit-image, nvidia-cusolver-cu12, matplotlib, torch, seaborn, pynndescent, umap-learn, torchvision
#   Attempting uninstall: tqdm━━━━━━━━━━━━━━━━━━━━  0/50 [mpmath]
#     Found existing installation: tqdm 4.67.1━━━━━━━━━━━━━  1/50 [tqdm]
#     Uninstalling tqdm-4.67.1:━━━━━━━━━━━━━━━━━━━━━━━━  1/50 [tqdm]
#       Successfully uninstalled tqdm-4.67.1━━━━━━━━━━━━━━━  1/50 [tqdm]
#   Attempting uninstall: pyparsing━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/50 [regex]
#     Found existing installation: pyparsing 3.2.3━━━━━━━━━━━━━━  4/50 [regex]
#     Uninstalling pyparsing-3.2.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/50 [regex]
#       Successfully uninstalled pyparsing-3.2.3━━━━━━━━━━━━━━━━━━━━  5/50 [pyparsing]
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/50 [nvidia-cublas-cu12]u12]
#     Found existing installation: numpy 2.3.2━━━━━━━━━━━━━━━━━━ 14/50 [nvidia-cublas-cu12]
#     Uninstalling numpy-2.3.2:╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/50 [numpy]las-cu12]
#       Successfully uninstalled numpy-2.3.2━━━━━━━━━━━━━━━━━━━━━━━━ 15/50 [numpy]
#   Attempting uninstall: narwhals0m━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/50 [networkx]
#     Found existing installation: narwhals 2.3.0━━━━━━━━━━━━━━━ 16/50 [networkx]
#     Uninstalling narwhals-2.3.0:━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/50 [narwhals]
#       Successfully uninstalled narwhals-2.3.0━━━━━━━━━━━━━━━━━━━━━ 17/50 [narwhals]
#   Attempting uninstall: kiwisolver0m━━━━━━━━━━━━━━━━━━━━━━━━━ 18/50 [llvmlite]
#     Found existing installation: kiwisolver 1.4.9━━━━━━━━━━━━━ 18/50 [llvmlite]
#     Uninstalling kiwisolver-1.4.9:90m━━━━━━━━━━━━━━━━━━━━━━━━━ 18/50 [llvmlite]
#       Successfully uninstalled kiwisolver-1.4.9━━━━━━━━━━━━━━━━━━━ 20/50 [kiwisolver]
#   Attempting uninstall: charset-normalizer━━━━━━━━━━━━━━━━━━━━ 24/50 [filelock]_resources]
#     Found existing installation: charset-normalizer 3.4.2━━━━━ 24/50 [filelock]
#     Uninstalling charset-normalizer-3.4.2:━━━━━━━━━━━━━━━━━━━━ 24/50 [filelock]
#       Successfully uninstalled charset-normalizer-3.4.2━━━━━━━━━━━ 25/50 [charset-normalizer]
#   Attempting uninstall: certifi0m╺━━━━━━━━━━━━━━━━━━━ 25/50 [charset-normalizer]
#     Found existing installation: certifi 2025.7.14━━━━━━━━━━━━━━━━ 26/50 [certifi]alizer]
#     Uninstalling certifi-2025.7.14:━━━━━━━━━━━━━━━━━━━ 26/50 [certifi]
#       Successfully uninstalled certifi-2025.7.14━━━━━━━━━━━━━━ 26/50 [certifi]
#   Attempting uninstall: requests╺━━━━━━━━━━━━━━━━ 29/50 [scipy]le]te]
#     Found existing installation: requests 2.32.490m━━━━━━━━━━━━━━━ 30/50 [requests]
#     Uninstalling requests-2.32.4:╺━━━━━━━━━━━━━━━ 30/50 [requests]
#       Successfully uninstalled requests-2.32.4━━━━━━━━━━━━━━━ 30/50 [requests]
#   Attempting uninstall: plotly0m╺━━━━━━━━━━━━━━━ 30/50 [requests]
#     Found existing installation: plotly 6.3.00m━━━━━━━━━━━━━━━ 30/50 [requests]
#     Uninstalling plotly-6.3.0:━━╸━━━━━━━━━━━━━━━ 31/50 [plotly]
#       Successfully uninstalled plotly-6.3.0━━━━━━━━━━━━━━━ 31/50 [plotly]
#   Attempting uninstall: pandas━━╸━━━━━━━━━━━━━━━ 31/50 [plotly]
#     Found existing installation: pandas 2.3.20m━━━━━━━━━━━━━━━ 31/50 [plotly]
#     Uninstalling pandas-2.3.2:━━━╸━━━━━━━━━━━━━━ 32/50 [pandas]
#       Successfully uninstalled pandas-2.3.2━━━━━━━━━━━━━━ 32/50 [pandas]
#   Attempting uninstall: contourpy━━━━━━╺━━━━━━━━ 39/50 [imageio]udnn-cu12]12]]]
#     Found existing installation: contourpy 1.3.3m━━━━━━━━ 39/50 [imageio]
#     Uninstalling contourpy-1.3.3:━━╺━━━━━━━━ 39/50 [imageio]
#       Successfully uninstalled contourpy-1.3.390m╺━━━━━━━ 40/50 [contourpy]
#   Attempting uninstall: matplotlib━━━━━━━━╺━━━━━ 43/50 [nvidia-cusolver-cu12]
#     Found existing installation: matplotlib 3.10.60m━━━━━ 43/50 [nvidia-cusolver-cu12]
#     Uninstalling matplotlib-3.10.6:━━━━━━━━╺━━━━ 44/50 [matplotlib]-cu12]
#       Successfully uninstalled matplotlib-3.10.6╺━━━━ 44/50 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50/50 [torchvision]chvision]p-learn]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyspark-client 4.0.1 requires googleapis-common-protos>=1.65.0, which is not installed.
# pyspark-client 4.0.1 requires grpcio>=1.67.0, which is not installed.
# pyspark-client 4.0.1 requires grpcio-status>=1.67.0, which is not installed.
# pyspark-client 4.0.1 requires pyarrow>=11.0.0, which is not installed.
# pyspark-connect 4.0.1 requires googleapis-common-protos>=1.65.0, which is not installed.
# pyspark-connect 4.0.1 requires grpcio>=1.67.0, which is not installed.
# pyspark-connect 4.0.1 requires grpcio-status>=1.67.0, which is not installed.
# pyspark-connect 4.0.1 requires pyarrow>=11.0.0, which is not installed.
# Successfully installed argcomplete-3.2.2 certifi-2025.8.3 charset-normalizer-3.4.3 contourpy-1.3.0 filelock-3.19.1 fsspec-2025.9.0 imageio-2.37.0 importlib_resources-6.5.2 joblib-1.4.2 kiwisolver-1.4.7 lazy_loader-0.4 llvmlite-0.43.0 matplotlib-3.9.2 mpmath-1.3.0 narwhals-2.7.0 networkx-3.2.1 numba-0.60.0 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.9.86 nvidia-nvtx-cu12-12.1.105 opencv-contrib-python-4.6.0.66 opencv-python-4.8.0.74 opencv-python-headless-4.6.0.66 pandas-2.3.3 plotly-6.3.1 pynndescent-0.5.13 pyparsing-3.0.9 regex-2023.12.25 requests-2.32.5 scikit-image-0.24.0 scikit-learn-1.6.1 scipy-1.13.1 seaborn-0.13.2 sympy-1.14.0 threadpoolctl-3.6.0 tifffile-2024.8.30 torch-2.2.2 torchvision-0.17.2 tqdm-4.65.0 umap-learn-0.5.9.post2

# %% [markdown]
# K means resnet gray not norm

# %%
! python3 k_means.py --embedding_file ../embeddings_files/resnet_embeddings_train_gray.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_gray.npz

# %%
!  python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_gray.npz

# %% [markdown]
# k means dino gray not norm

# %%
 !   python3 k_means.py --embedding_file ../embeddings_files/dino_embeddings_train_gray.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_gray.npz

# %%
!     python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_gray.npz

# %% [markdown]
# k means resnet gray norm

# %%
!    python3 k_means.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_resnet_gray_normalised.npz

# %%
!    python3 ami.py --clustered_file ../k_means_clusters/k_means_resnet_gray_normalised.npz

# %% [markdown]
# k means dino gray norm

# %%
 !   python3 k_means.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../k_means_clusters/k_means_dino_gray_normalised.npz

# %%
!    python3 ami.py --clustered_file ../k_means_clusters/k_means_dino_gray_normalised.npz

# %% [markdown]
# Agglomerative clustering resnet gray not norm

# %%
    ! python3 agglomerative_clustering.py --embedding_file ../embeddings_files/resnet_embeddings_train_gray.npz --n_clusters 9 --output_file ../ac_cluster_files/agglomerative_clusters_resnet_gray.npz
# Out:
# 🔍 Running K-Means clustering...
# ✅ Saved clustered data to ../k_means_clusters/k_means_resnet_rgb_test.npz

# %%
!    python3 ami.py --clustered_file ../ac_cluster_files/agglomerative_clusters_resnet_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.2221

# %% [markdown]
# agglomerative clustering dino gray not norm

# %%
!    python3 agglomerative_clustering.py --embedding_file ../embeddings_files/dino_embeddings_train_gray.npz --n_clusters 9 --output_file ../ac_cluster_files/agglomerative_clusters_dino_gray.npz
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../ac_cluster_files/agglomerative_clusters_dino_rgb.npz

# %%
!    python3 ami.py --clustered_file ../ac_cluster_files/agglomerative_clusters_dino_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.2898

# %% [markdown]
# Agglomerative clustering Normalised  resnet gray

# %%
!    python3 agglomerative_clustering.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../ac_cluster_files/ac_resnet_gray_normalised.npz
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../ac_cluster_files/ac_resnet_rgb_normalised.npz

# %%
 !   python3 ami.py --clustered_file ../ac_cluster_files/ac_resnet_gray_normalised.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.2165

# %% [markdown]
# ac dino gray normalised

# %%
!    python3 agglomerative_clustering.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../ac_cluster_files/ac_dino_gray_normalised.npz
# Out:
# 🔍 Running Agglomerative clustering...
# ✅ Saved clustered data to ../ac_cluster_files/ac_dino_rgb_normalised.npz

# %%
!    python3 ami.py --clustered_file ../ac_cluster_files/ac_dino_gray_normalised.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.3267

# %% [markdown]
# HDBSCAN  resnet gray not norm

# %%
!    python3 hdbscan_clustering.py --embedding_file ../embeddings_files/resnet_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../hdbscan_clusters/hdbscan_resnet_gray.npz
# Out:
# 🔍 Running HDBSCAN clustering...
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../hdbscan_clusters/hdbscan_resnet_rgb.npz

# %%
!    python3 ami.py --clustered_file ../hdbscan_clusters/hdbscan_resnet_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.0075

# %% [markdown]
# hdbscan dino gray not notm

# %%
!    python3 hdbscan_clustering.py --embedding_file ../embeddings_files/dino_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../hdbscan_clusters/hdbscan_dino_gray.npz
# Out:
# 🔍 Running HDBSCAN clustering...
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../hdbscan_clusters/hdbscan_dino_rgb.npz

# %%
!    python3 ami.py --clustered_file ../hdbscan_clusters/hdbscan_dino_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.1985

# %% [markdown]
# HDBSCAN normalised resnet rgb

# %%
!    python3 hdbscan_clustering.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train.npz --min_cluster_size 10 --output_file ../hdbscan_clusters/hdbscan_resnet_rgb_normalised.npz
# Out:
# 🔍 Running HDBSCAN clustering...
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
!    python3 ami.py --clustered_file ../hdbscan_clusters/hdbscan_resnet_rgb_normalised.npz
# Out:
# Traceback (most recent call last):
#   File "/work/Finding_a_nemo/scripts/ami.py", line 47, in <module>
#     main()
#   File "/work/Finding_a_nemo/scripts/ami.py", line 37, in main
#     data = np.load(args.clustered_file, allow_pickle=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/numpy/lib/npyio.py", line 427, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../hdbscan_clusters/hdbscan_resnet_rgb_normalised.npz'
# ^C

# %% [markdown]
# HDBSCAN resnet gray normalised

# %%
!    python3 hdbscan_clustering.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../hdbscan_clusters/hdbscan_resnet_gray_normalised.npz
# Out:
# 🔍 Running HDBSCAN clustering...
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Saved clustered data to ../hdbscan_clusters/hdbscan_dino_rgb_normalised.npz

# %%
!    python3 ami.py --clustered_file ../hdbscan_clusters/hdbscan_resnet_gray_normalised.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.1973

# %% [markdown]
# HDBSCAN dino gray normalised

# %%
!    python3 hdbscan_clustering.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../hdbscan_clusters/hdbscan_dino_gray_normalised.npz

# %%
!    python3 ami.py --clustered_file ../hdbscan_clusters/hdbscan_dino_gray_normalised.npz

# %% [markdown]
# UMAP + K means resnet gray not norm

# %%
!     python3 umap_k_means.py --embedding_file ../embeddings_files/resnet_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_k_means_clusters/umap_km_resnet_gray.npz
# Out:
# ✅ Saved clustered data to ../umap_ac_clusters/umap_ac_resnet_rgb.npz

# %%
!    python3 ami.py --clustered_file ../umap_k_means_clusters/umap_km_resnet_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.2516

# %% [markdown]
# UMAP k means dino gray not norm

# %%
!    python3 umap_k_means.py --embedding_file ../embeddings_files/dino_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_k_means_clusters/umap_km_dino_gray.npz
# Out:
# ✅ Saved clustered data to ../umap_ac_clusters/umap_ac_dino_rgb.npz

# %%
!    python3 ami.py --clustered_file ../umap_k_means_clusters/umap_km_dino_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.3765

# %% [markdown]
# UMAP K means resnet gray normalised

# %%
!    python3 umap_k_means.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_k_means_clusters/umap_km_resnet_normalised_gray.npz

# %%
!    python3 ami.py --clustered_file ../umap_k_means_clusters/umap_km_resnet_normalised_gray.npz

# %% [markdown]
# Umap k means dino gray normalised

# %%
 !   python3 umap_k_means.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_k_means_clusters/umap_km_dino_normalised_gray.npz

# %%
!    python3 ami.py --clustered_file ../umap_k_means_clusters/umap_km_dino_normalised_gray.npz

# %% [markdown]
# UMAP+AC resnet gray not norm

# %%
!     python3 umap_ac.py --embedding_file ../embeddings_files/resnet_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_ac_clusters/umap_ac_resnet_gray.npz
# Out:
# ✅ Saved clustered data to ../umap_ac_clusters/umap_ac_resnet_normalised_rgb.npz

# %%
!    python3 ami.py --clustered_file ../umap_ac_clusters/umap_ac_resnet_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.2799

# %% [markdown]
# Umap ac dino gray not norm

# %%
!    python3 umap_ac.py --embedding_file ../embeddings_files/dino_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_ac_clusters/umap_ac_dino_gray.npz
# Out:
# ✅ Saved clustered data to ../umap_ac_clusters/umap_ac_dino_normalised_rgb.npz

# %%
!    python3 ami.py --clustered_file ../umap_ac_clusters/umap_ac_dino_gray.npz
# Out:
# ✅ Adjusted Mutual Information (AMI): 0.3895

# %% [markdown]
# UMAP ac resnet gray norm

# %%
!    python3 umap_ac.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_ac_clusters/umap_ac_resnet_normalised_gray.npz

# %%
!    python3 ami.py --clustered_file ../umap_ac_clusters/umap_ac_resnet_normalised_gray.npz

# %% [markdown]
# Umap Ac dino gray norm

# %%
 !   python3 umap_ac.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_train_gray.npz --n_clusters 9 --output_file ../umap_ac_clusters/umap_ac_dino_normalised_gray.npz

# %%
!     python3 ami.py --clustered_file ../umap_ac_clusters/umap_ac_dino_normalised_gray.npz

# %% [markdown]
# UMAP + HDBSCAN  resnet rgb not norm

# %%
!     python3 umap_hdbscan.py --embedding_file ../embeddings_files/resnet_embeddings_train.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_rgb.npz

# %%
 !   python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_rgb.npz

# %% [markdown]
# umap hdbscan resnet gray not norm

# %%
!     python3 umap_hdbscan.py --embedding_file ../embeddings_files/resnet_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_gray.npz

# %%
    python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_gray.npz

# %% [markdown]
# UMAP + HDBSCAN dino rgb not norm

# %%
 !   python3 umap_hdbscan.py --embedding_file ../embeddings_files/dino_embeddings_train.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_dino_rgb.npz

# %%
!    python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_dino_rgb.npz

# %% [markdown]
# umap hdbscan dino gray not norm

# %%
!    python3 umap_hdbscan.py --embedding_file ../embeddings_files/dino_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_dino_gray.npz

# %%
!     python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_dino_gray.npz

# %% [markdown]
# Umap hdbscan resnet rgb norm

# %%
!    python3 umap_hdbscan.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_normalised_rgb.npz

# %%
!     python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_normalised_rgb.npz

# %% [markdown]
# umap hdbscan resnet gray norm

# %%
 !   python3 umap_hdbscan.py --embedding_file ../normalised_embeddings/resnet_normalised_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_normalised_gray.npz

# %%
!     python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_resnet_normalised_gray.npz

# %% [markdown]
# Umap hdbscan dino rgb norm

# %%
!    python3 umap_hdbscan.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_train.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_dino_normalised_rgb.npz

# %%
!    python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_dino_normalised_rgb.npz

# %% [markdown]
# umap hdbscan dino gray norm

# %%
!    python3 umap_hdbscan.py --embedding_file ../normalised_embeddings/dino_normalised_embeddings_train_gray.npz --min_cluster_size 10 --output_file ../umap_hdbscan_clusters/umap_hdbscan_dino_normalised_gray.npz

# %%
!    python3 ami.py --clustered_file ../umap_hdbscan_clusters/umap_hdbscan_dino_normalised_gray.npz
